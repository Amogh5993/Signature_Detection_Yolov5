# %% [markdown]
# importing necessary libraries

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import shutil
import os, sys, random
from glob import glob
import pandas as pd
from shutil import copyfile
import pandas as pd
from sklearn import preprocessing, model_selection
import matplotlib.pyplot as plt
from matplotlib import patches
import numpy as np
import os
# %matplotlib inline

# %% [markdown]
# Cloning yolo git repository

# %%
# !git clone  'https://github.com/ultralytics/yolov5.git'

# !pip install -qr '/content/yolov5/requirements.txt'  # install dependencies
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15305, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 15305 (delta 0), reused 1 (delta 0), pack-reused 15300
# Receiving objects: 100% (15305/15305), 14.13 MiB | 13.97 MiB/s, done.
# Resolving deltas: 100% (10497/10497), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 68.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 67.6.0 which is incompatible.

# %% [markdown]
# here i'm creating the tobacco_data.yaml file in the yolov5 cloned directory

# %%
# !echo -e 'train: /content/drive/MyDrive/tobacco_data_zhugy/tobacco_yolo_format/images/train\n val: /content/drive/MyDrive/tobacco_data_zhugy/tobacco_yolo_format/images/valid\n\n nc: 2\n names: ['DLLogo', 'DLSignature']' >> tobacco_data.yaml
# !cat tobacco_data.yaml
# Out:
# train: /content/drive/MyDrive/tobacco_data_zhugy/tobacco_yolo_format/images/train
#  val: /content/drive/MyDrive/tobacco_data_zhugy/tobacco_yolo_format/images/valid
#
#  nc: 2
#  names: [DLLogo, DLSignature]

# %%
# Setting the model parameters
shutil.copyfile('tobacco_data.yaml', 'yolov5/tobacco_data.yaml') # copying the custom_dataset.yaml file to the project repo
# setting number of classes to two (since the tobacco 800 dataset contains 2 classes, Logo & Signature)
# !sed -i 's/nc: 80/nc: 2/g' ./yolov5/models/yolov5x.yaml

# %%
# !python yolov5/train.py --img 640 --batch 10 --epochs 100 --data tobacco_data.yaml --cfg /content/yolov5/models/yolov5x.yaml --name Tobacco-run
# Out:
# train: weights=yolov5/yolov5s.pt, cfg=/content/yolov5/models/yolov5x.yaml, data=tobacco_data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=10, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=Tobacco-run, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python yolov5/detect.py --source /content/drive/MyDrive/tobacco_data_zhugy/tobacco_yolo_format/images/valid/mta60c00.jpg --weights '/content/yolov5/runs/train/Tobacco-run4/weights/best.pt' \
 --hide-labels --hide-conf --classes 1 --line-thickness 2
# Out:
# detect: weights=['/content/yolov5/runs/train/Tobacco-run4/weights/best.pt'], source=/content/drive/MyDrive/tobacco_data_zhugy/tobacco_yolo_format/images/valid/mta60c00.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[1], agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=2, hide_labels=True, hide_conf=True, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5x summary: 322 layers, 86180143 parameters, 0 gradients, 203.8 GFLOPs
# image 1/1 /content/drive/MyDrive/tobacco_data_zhugy/tobacco_yolo_format/images/valid/mta60c00.jpg: 640x512 1 DLSignature, 64.0ms
# Speed: 1.2ms pre-process, 64.0ms inference, 1.8ms NMS per image at shape (1, 3, 640, 640)
# ...
